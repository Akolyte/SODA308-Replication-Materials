# %% [markdown]
# # Tweet Collection from the Twitter API

# %% [markdown]
# The categories that we are predicting for this project are **Best Picture**, **Best Actor**, **Best Actress**, **Best Supporting Actor**, and **Best Supporting Actress**.

# %% [markdown]
# The technical goal is to store tweets under jsons for each Oscar Nominee. There will be one json for each category.
#
# tweets -> keyword -> nominee -> json

# %% [markdown]
# ### Getting authentication to collect

# %%
import json
import tweepy
import pandas as pd

# %%
#keys/secrets
credentials = {}
credentials['CONSUMER_KEY'] = ""
credentials['CONSUMER_SECRET'] = ""
credentials['ACCESS_TOKEN'] = ""
credentials['ACCESS_SECRET'] = ""

with open("twitter_credentials.json", "w") as f:
    json.dump(credentials, f)

# %%
with open("twitter_credentials.json", "r") as f:
    creds = json.load(f)
    
auth = tweepy.OAuthHandler(creds['CONSUMER_KEY'], creds['CONSUMER_SECRET'])
auth.set_access_token(creds['ACCESS_TOKEN'], creds['ACCESS_SECRET'])

api = tweepy.API(auth, wait_on_rate_limit = True,
                wait_on_rate_limit_notify = True)
try:
    api.verify_credentials()
    print("Authentication OK")
except:
    print("Error during Authentication")
# Out:
# Authentication OK

# %%
# Code for collecting tweets for a list of keywords
def collectTweets(key, query, df, dateList):
    for date in dateList:
        for tweet in api.search(q=query, lang = "en", count = 100, toDate = date):
            actress_name = key
            text = tweet.text
            favorite_count = tweet.favorite_count
            retweet_count = tweet.retweet_count
            date_posted = tweet.created_at 
            df.loc[len(df.index)] = [key, text, favorite_count, retweet_count, date]

# %%
n = ["Anthony Hopkins", "Riz Ahmed", "Chadwick Boseman", "Gary Oldman", "Steven Yeun"]

nominees_keyword_dict = {n[0]:"%23oscars%20%23anthonyhopkins%20-filter%3Aretweets", 
                         n[1]:"%23oscars%20%23rizahmed%20-filter%3Aretweets", 
                         n[2]:"%23oscars%20%23chadwickboseman%20-filter%3Aretweets", 
                         n[3]:"%23oscars%20%23garyoldman%20-filter%3Aretweets", 
                         n[4]:"%23oscars%20%23stevenyeun%20-filter%3Aretweets"}

tweets_df = pd.DataFrame(columns = ["actor_name", "text", "favorite_count", "retweet_count", "date"])

dates = ["Sat Apr 23 12:00:00 +0000 2021",
         "Sat Apr 22 12:00:00 +0000 2021",
         "Sat Apr 21 12:00:00 +0000 2021",
         "Sat Apr 20 12:00:00 +0000 2021",
         "Sat Apr 19 12:00:00 +0000 2021",
         "Sat Apr 18 12:00:00 +0000 2021",
         "Sat Apr 17 12:00:00 +0000 2021",
         "Sat Apr 16 12:00:00 +0000 2021"]

# %%
# Collecting tweets for best actress
for key in nominees_keyword_dict:
    collectTweets(key, nominees_keyword_dict[key], tweets_df, dates)

# %%
tweets_df
# Out:
#            actor_name                                               text  \
# 0     Anthony Hopkins  RT @La_Cle_ANGLAISE: #actualités 🇺🇸\n#Oscars20...
# 1     Anthony Hopkins  Anthony Hopkins won the Best Actor award for T...
# 2     Anthony Hopkins  RT @opendoorpeople: Let’s make sure we note -\...
# 3     Anthony Hopkins  RT @JoshSabarra: OSCAR THROWBACK: Anthony Hopk...
# 4     Anthony Hopkins  RT @JoshSabarra: OSCAR THROWBACK: Anthony Hopk...
# ...               ...                                                ...
# 3947      Steven Yeun  Taylor, Michigan shout-out on the Oscars: Who ...
# 3948      Steven Yeun  The newest #BestActor #Oscar winner just walke...
# 3949      Steven Yeun  RT @pinkvilla: The cast of Minari set the Osca...
# 3950      Steven Yeun  Steven Yeun @the Oscars... still waiting for B...
# 3951      Steven Yeun  Ok Blue is his Color💙#stevenyeun #Oscars #Acad...
#
#      favorite_count retweet_count                            date
# 0                 0             2  Sat Apr 23 12:00:00 +0000 2021
# 1                 0             0  Sat Apr 23 12:00:00 +0000 2021
# 2                 0            49  Sat Apr 23 12:00:00 +0000 2021
# 3                 0            31  Sat Apr 23 12:00:00 +0000 2021
# 4                 0            31  Sat Apr 23 12:00:00 +0000 2021
# ...             ...           ...                             ...
# 3947              5             0  Sat Apr 16 12:00:00 +0000 2021
# 3948              0             0  Sat Apr 16 12:00:00 +0000 2021
# 3949              0             4  Sat Apr 16 12:00:00 +0000 2021
# 3950              0             0  Sat Apr 16 12:00:00 +0000 2021
# 3951              1             0  Sat Apr 16 12:00:00 +0000 2021
#
# [3952 rows x 5 columns]

# %%
# Number of tweets for Carey Mulligan for the Oscars prior to them taking place
tweets_df[tweets_df["actor_name"] == n[0]]
# Out:
#           actor_name                                               text  \
# 0    Anthony Hopkins  RT @La_Cle_ANGLAISE: #actualités 🇺🇸\n#Oscars20...
# 1    Anthony Hopkins  Anthony Hopkins won the Best Actor award for T...
# 2    Anthony Hopkins  RT @opendoorpeople: Let’s make sure we note -\...
# 3    Anthony Hopkins  RT @JoshSabarra: OSCAR THROWBACK: Anthony Hopk...
# 4    Anthony Hopkins  RT @JoshSabarra: OSCAR THROWBACK: Anthony Hopk...
# ..               ...                                                ...
# 795  Anthony Hopkins  RT @JoshSabarra: OSCAR THROWBACK: Anthony Hopk...
# 796  Anthony Hopkins  Folks aren’t feeling how the #Oscars seemingly...
# 797  Anthony Hopkins  RT @opendoorpeople: Let’s make sure we note -\...
# 798  Anthony Hopkins  RT @cyrilicioushawk: #AnthonyHopkins thanks an...
# 799  Anthony Hopkins  RT @opendoorpeople: Let’s make sure we note -\...
#
#     favorite_count retweet_count                            date
# 0                0             2  Sat Apr 23 12:00:00 +0000 2021
# 1                0             0  Sat Apr 23 12:00:00 +0000 2021
# 2                0            49  Sat Apr 23 12:00:00 +0000 2021
# 3                0            31  Sat Apr 23 12:00:00 +0000 2021
# 4                0            31  Sat Apr 23 12:00:00 +0000 2021
# ..             ...           ...                             ...
# 795              0            31  Sat Apr 16 12:00:00 +0000 2021
# 796              4             0  Sat Apr 16 12:00:00 +0000 2021
# 797              0            49  Sat Apr 16 12:00:00 +0000 2021
# 798              0            31  Sat Apr 16 12:00:00 +0000 2021
# 799              0            49  Sat Apr 16 12:00:00 +0000 2021
#
# [800 rows x 5 columns]

# %%
tweets_df[tweets_df["actor_name"] == n[1]]
# Out:
#      actor_name                                               text  \
# 800   Riz Ahmed  RT @ogseran: Riz Ahmed may have been nominated...
# 801   Riz Ahmed  Recently a video went viral ft Riz Ahmed fixin...
# 802   Riz Ahmed  RT @filmfare: The moment that’s got everyone t...
# 803   Riz Ahmed  @rizwanahmed Aw, shut up! #academyawards #osca...
# 804   Riz Ahmed  Idk why everyone’s is calling him “controlling...
# ...         ...                                                ...
# 1595  Riz Ahmed  RT @NetsNews21: 🎖️Oscars 2021: Check out the v...
# 1596  Riz Ahmed  RT @NetsNews21: 🎖️Oscars 2021: Check out the v...
# 1597  Riz Ahmed  RT @NetsNews21: 🎖️Oscars 2021: Check out the v...
# 1598  Riz Ahmed  RT @khaleejtimes: #Oscars2021: #RizAhmed and h...
# 1599  Riz Ahmed  RT @khaleejtimes: #Oscars2021: #RizAhmed and h...
#
#      favorite_count retweet_count                            date
# 800               0             0  Sat Apr 23 12:00:00 +0000 2021
# 801               0             0  Sat Apr 23 12:00:00 +0000 2021
# 802               0            26  Sat Apr 23 12:00:00 +0000 2021
# 803               0             0  Sat Apr 23 12:00:00 +0000 2021
# 804               1             0  Sat Apr 23 12:00:00 +0000 2021
# ...             ...           ...                             ...
# 1595              0            68  Sat Apr 16 12:00:00 +0000 2021
# 1596              0            68  Sat Apr 16 12:00:00 +0000 2021
# 1597              0            68  Sat Apr 16 12:00:00 +0000 2021
# 1598              0             4  Sat Apr 16 12:00:00 +0000 2021
# 1599              0             4  Sat Apr 16 12:00:00 +0000 2021
#
# [800 rows x 5 columns]

# %%
tweets_df[tweets_df["actor_name"] == n[2]]
# Out:
#             actor_name                                               text  \
# 1600  Chadwick Boseman  RT @tonetalks: “Did Daniel Kaluuya Win Chadwic...
# 1601  Chadwick Boseman  RT @tonetalks: “Did Daniel Kaluuya Win Chadwic...
# 1602  Chadwick Boseman  RT @ABC7: #ChadwickBoseman had been heavily fa...
# 1603  Chadwick Boseman  RT @tonetalks: “Did Daniel Kaluuya Win Chadwic...
# 1604  Chadwick Boseman  “Did Daniel Kaluuya Win Chadwick Boseman's Osc...
# ...                ...                                                ...
# 2395  Chadwick Boseman  RT @ComicBook: #ChadwickBoseman gets an NFT tr...
# 2396  Chadwick Boseman  They...made.... an....#NFT .....of...#Chadwick...
# 2397  Chadwick Boseman  RT @dilani_r: #IrrfanKhan &amp; #ChadwickBosem...
# 2398  Chadwick Boseman  Folks aren’t feeling how the #Oscars seemingly...
# 2399  Chadwick Boseman  RT @GraceRandolph: Listen, no matter how u fee...
#
#      favorite_count retweet_count                            date
# 1600              0             3  Sat Apr 23 12:00:00 +0000 2021
# 1601              0             3  Sat Apr 23 12:00:00 +0000 2021
# 1602              0            11  Sat Apr 23 12:00:00 +0000 2021
# 1603              0             3  Sat Apr 23 12:00:00 +0000 2021
# 1604             13             3  Sat Apr 23 12:00:00 +0000 2021
# ...             ...           ...                             ...
# 2395              0           512  Sat Apr 16 12:00:00 +0000 2021
# 2396              0             0  Sat Apr 16 12:00:00 +0000 2021
# 2397              0            91  Sat Apr 16 12:00:00 +0000 2021
# 2398              4             0  Sat Apr 16 12:00:00 +0000 2021
# 2399              0           164  Sat Apr 16 12:00:00 +0000 2021
#
# [800 rows x 5 columns]

# %%
tweets_df[tweets_df["actor_name"] == n[3]]
# Out:
#        actor_name                                               text  \
# 2400  Gary Oldman  RT @PaulSmithDesign: In 2012, #GaryOldman chos...
# 2401  Gary Oldman  RT @GettyVIP: Gary Oldman of @MankFilm attends...
# 2402  Gary Oldman  RT @PaulSmithDesign: In 2012, #GaryOldman chos...
# 2403  Gary Oldman  RT @PaulSmithDesign: In 2012, #GaryOldman chos...
# 2404  Gary Oldman  RT @PaulSmithDesign: In 2012, #GaryOldman chos...
# ...           ...                                                ...
# 3147  Gary Oldman  🎬 Mank \n#garyoldman #Oscars https://t.co/EM74...
# 3148  Gary Oldman  Victorias en MEJOR ACTOR 🎭\n\n#ChadwickBoseman...
# 3149  Gary Oldman  With the @TheAcademy awards #Oscars coming up ...
# 3150  Gary Oldman  #CountdowntoOscars\nNominated film @MankFilm i...
# 3151  Gary Oldman  Please check out my review for the movie Mank:...
#
#      favorite_count retweet_count                            date
# 2400              0             9  Sat Apr 23 12:00:00 +0000 2021
# 2401              0            15  Sat Apr 23 12:00:00 +0000 2021
# 2402              0             9  Sat Apr 23 12:00:00 +0000 2021
# 2403              0             9  Sat Apr 23 12:00:00 +0000 2021
# 2404              0             9  Sat Apr 23 12:00:00 +0000 2021
# ...             ...           ...                             ...
# 3147              0             0  Sat Apr 16 12:00:00 +0000 2021
# 3148              0             0  Sat Apr 16 12:00:00 +0000 2021
# 3149              0             0  Sat Apr 16 12:00:00 +0000 2021
# 3150              0             0  Sat Apr 16 12:00:00 +0000 2021
# 3151              0             0  Sat Apr 16 12:00:00 +0000 2021
#
# [752 rows x 5 columns]

# %%
tweets_df[tweets_df["actor_name"] == n[4]]
# Out:
#        actor_name                                               text  \
# 3152  Steven Yeun  RT @gucci: Nominee for Best Actor in a Leading...
# 3153  Steven Yeun  These are the top 10 people being mentioned wi...
# 3154  Steven Yeun  #LIFESTYLE\n\n#StevenYeun’s #Oscars Hair Pays ...
# 3155  Steven Yeun  can it do it? It’s “Tenet”! \n(@fionadourif @H...
# 3156  Steven Yeun  As far as I'm concerned, the biggest winner of...
# ...           ...                                                ...
# 3947  Steven Yeun  Taylor, Michigan shout-out on the Oscars: Who ...
# 3948  Steven Yeun  The newest #BestActor #Oscar winner just walke...
# 3949  Steven Yeun  RT @pinkvilla: The cast of Minari set the Osca...
# 3950  Steven Yeun  Steven Yeun @the Oscars... still waiting for B...
# 3951  Steven Yeun  Ok Blue is his Color💙#stevenyeun #Oscars #Acad...
#
#      favorite_count retweet_count                            date
# 3152              0            75  Sat Apr 23 12:00:00 +0000 2021
# 3153              1             0  Sat Apr 23 12:00:00 +0000 2021
# 3154              0             0  Sat Apr 23 12:00:00 +0000 2021
# 3155              0             0  Sat Apr 23 12:00:00 +0000 2021
# 3156              1             0  Sat Apr 23 12:00:00 +0000 2021
# ...             ...           ...                             ...
# 3947              5             0  Sat Apr 16 12:00:00 +0000 2021
# 3948              0             0  Sat Apr 16 12:00:00 +0000 2021
# 3949              0             4  Sat Apr 16 12:00:00 +0000 2021
# 3950              0             0  Sat Apr 16 12:00:00 +0000 2021
# 3951              1             0  Sat Apr 16 12:00:00 +0000 2021
#
# [800 rows x 5 columns]

# %%
tweets_df[tweets_df["actor_name"] == n[4]].iloc[0]
# Out:
# actor_name                                              Steven Yeun
# text              RT @gucci: Nominee for Best Actor in a Leading...
# favorite_count                                                    0
# retweet_count                                                    75
# date                                 Sat Apr 23 12:00:00 +0000 2021
# Name: 3152, dtype: object

# %%
tweets_df.to_pickle("best_actor.pkl")

# %%
train = pd.read_pickle("best_actor.pkl")

# %% [markdown]
# # Text Processing

# %%
train
# Out:
#            actor_name                                               text  \
# 0     Anthony Hopkins  RT @La_Cle_ANGLAISE: #actualités 🇺🇸\n#Oscars20...
# 1     Anthony Hopkins  Anthony Hopkins won the Best Actor award for T...
# 2     Anthony Hopkins  RT @opendoorpeople: Let’s make sure we note -\...
# 3     Anthony Hopkins  RT @JoshSabarra: OSCAR THROWBACK: Anthony Hopk...
# 4     Anthony Hopkins  RT @JoshSabarra: OSCAR THROWBACK: Anthony Hopk...
# ...               ...                                                ...
# 3947      Steven Yeun  Taylor, Michigan shout-out on the Oscars: Who ...
# 3948      Steven Yeun  The newest #BestActor #Oscar winner just walke...
# 3949      Steven Yeun  RT @pinkvilla: The cast of Minari set the Osca...
# 3950      Steven Yeun  Steven Yeun @the Oscars... still waiting for B...
# 3951      Steven Yeun  Ok Blue is his Color💙#stevenyeun #Oscars #Acad...
#
#      favorite_count retweet_count                            date
# 0                 0             2  Sat Apr 23 12:00:00 +0000 2021
# 1                 0             0  Sat Apr 23 12:00:00 +0000 2021
# 2                 0            49  Sat Apr 23 12:00:00 +0000 2021
# 3                 0            31  Sat Apr 23 12:00:00 +0000 2021
# 4                 0            31  Sat Apr 23 12:00:00 +0000 2021
# ...             ...           ...                             ...
# 3947              5             0  Sat Apr 16 12:00:00 +0000 2021
# 3948              0             0  Sat Apr 16 12:00:00 +0000 2021
# 3949              0             4  Sat Apr 16 12:00:00 +0000 2021
# 3950              0             0  Sat Apr 16 12:00:00 +0000 2021
# 3951              1             0  Sat Apr 16 12:00:00 +0000 2021
#
# [3952 rows x 5 columns]

# %%
import nltk
from nltk.corpus import stopwords
additional  = ['rt','rts','retweet']
swords = set().union(stopwords.words('english'),additional)

# %%
train['processed_text'] = train['text'].str.lower()\
          .str.replace('(@[a-z0-9]+)\w+',' ')\
          .str.replace('(http\S+)', ' ')\
          .str.replace('([^0-9a-z \t])',' ')\
          .str.replace(' +',' ')\
          .str.replace('(@[0-9]+)\w+',' ')\
          .apply(lambda x: [i for i in x.split() if not i in swords])

# %%
from nltk.stem import PorterStemmer
ps = PorterStemmer()
train['stemmed'] = train['processed_text'].apply(lambda x: [ps.stem(i) for i in x if i != ''])

# %%
train["text2"] = train["processed_text"].str.join(" ")

# %%
train["text3"] = train["stemmed"].str.join(" ")

# %%
train
# Out:
#            actor_name                                               text  \
# 0     Anthony Hopkins  RT @La_Cle_ANGLAISE: #actualités 🇺🇸\n#Oscars20...
# 1     Anthony Hopkins  Anthony Hopkins won the Best Actor award for T...
# 2     Anthony Hopkins  RT @opendoorpeople: Let’s make sure we note -\...
# 3     Anthony Hopkins  RT @JoshSabarra: OSCAR THROWBACK: Anthony Hopk...
# 4     Anthony Hopkins  RT @JoshSabarra: OSCAR THROWBACK: Anthony Hopk...
# ...               ...                                                ...
# 3947      Steven Yeun  Taylor, Michigan shout-out on the Oscars: Who ...
# 3948      Steven Yeun  The newest #BestActor #Oscar winner just walke...
# 3949      Steven Yeun  RT @pinkvilla: The cast of Minari set the Osca...
# 3950      Steven Yeun  Steven Yeun @the Oscars... still waiting for B...
# 3951      Steven Yeun  Ok Blue is his Color💙#stevenyeun #Oscars #Acad...
#
#      favorite_count retweet_count                            date  \
# 0                 0             2  Sat Apr 23 12:00:00 +0000 2021
# 1                 0             0  Sat Apr 23 12:00:00 +0000 2021
# 2                 0            49  Sat Apr 23 12:00:00 +0000 2021
# 3                 0            31  Sat Apr 23 12:00:00 +0000 2021
# 4                 0            31  Sat Apr 23 12:00:00 +0000 2021
# ...             ...           ...                             ...
# 3947              5             0  Sat Apr 16 12:00:00 +0000 2021
# 3948              0             0  Sat Apr 16 12:00:00 +0000 2021
# 3949              0             4  Sat Apr 16 12:00:00 +0000 2021
# 3950              0             0  Sat Apr 16 12:00:00 +0000 2021
# 3951              1             0  Sat Apr 16 12:00:00 +0000 2021
#
#                                          processed_text  \
# 0     [actualit, oscars2021, chlo, zhao, made, histo...
# 1     [anthony, hopkins, best, actor, award, father,...
# 2     [let, make, sure, note, british, working, clas...
# 3     [oscar, throwback, anthony, hopkins, best, thi...
# 4     [oscar, throwback, anthony, hopkins, best, thi...
# ...                                                 ...
# 3947  [taylor, michigan, shout, oscars, bingo, card,...
# 3948  [newest, bestactor, oscar, winner, walked, ste...
# 3949  [cast, minari, set, oscars, red, carpet, aligh...
# 3950  [steven, yeun, oscars, still, waiting, best, a...
# 3951  [ok, blue, color, stevenyeun, oscars, academya...
#
#                                                 stemmed  \
# 0     [actualit, oscars2021, chlo, zhao, made, histo...
# 1     [anthoni, hopkin, best, actor, award, father, ...
# 2     [let, make, sure, note, british, work, class, ...
# 3     [oscar, throwback, anthoni, hopkin, best, thin...
# 4     [oscar, throwback, anthoni, hopkin, best, thin...
# ...                                                 ...
# 3947  [taylor, michigan, shout, oscar, bingo, card, ...
# 3948  [newest, bestactor, oscar, winner, walk, step,...
# 3949  [cast, minari, set, oscar, red, carpet, alight...
# 3950  [steven, yeun, oscar, still, wait, best, actor...
# 3951  [ok, blue, color, stevenyeun, oscar, academyaw...
#
#                                                   text2  \
# 0     actualit oscars2021 chlo zhao made history fir...
# 1     anthony hopkins best actor award father becomi...
# 2     let make sure note british working class talen...
# 3     oscar throwback anthony hopkins best think cam...
# 4     oscar throwback anthony hopkins best think cam...
# ...                                                 ...
# 3947  taylor michigan shout oscars bingo card steven...
# 3948  newest bestactor oscar winner walked steps ste...
# 3949  cast minari set oscars red carpet alight alan ...
# 3950  steven yeun oscars still waiting best actor ca...
# 3951      ok blue color stevenyeun oscars academyawards
#
#                                                   text3
# 0     actualit oscars2021 chlo zhao made histori fir...
# 1     anthoni hopkin best actor award father becom o...
# 2     let make sure note british work class talent e...
# 3     oscar throwback anthoni hopkin best think camp...
# 4     oscar throwback anthoni hopkin best think camp...
# ...                                                 ...
# 3947  taylor michigan shout oscar bingo card steveny...
# 3948  newest bestactor oscar winner walk step steven...
# 3949  cast minari set oscar red carpet alight alan k...
# 3950  steven yeun oscar still wait best actor catego...
# 3951        ok blue color stevenyeun oscar academyaward
#
# [3952 rows x 9 columns]

# %% [markdown]
# # Calculating Average Sentiment Scores

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\Hojin\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
sia = SentimentIntensityAnalyzer()

# %%
def sentiment_calcnltk(text):
    try:
        return sia.polarity_scores(text)
    except:
        return None

# %%
train['NLTKsentiment_raw'] = train["text3"].apply(sentiment_calcnltk)

# %%
iterate = list(train["NLTKsentiment_raw"])
compoundList = []
for t in iterate:
    compound = t["compound"]
    compoundList.append(compound)
train["NLTKsentiment"] = compoundList

# %%
train
# Out:
#            actor_name                                               text  \
# 0     Anthony Hopkins  RT @La_Cle_ANGLAISE: #actualités 🇺🇸\n#Oscars20...
# 1     Anthony Hopkins  Anthony Hopkins won the Best Actor award for T...
# 2     Anthony Hopkins  RT @opendoorpeople: Let’s make sure we note -\...
# 3     Anthony Hopkins  RT @JoshSabarra: OSCAR THROWBACK: Anthony Hopk...
# 4     Anthony Hopkins  RT @JoshSabarra: OSCAR THROWBACK: Anthony Hopk...
# ...               ...                                                ...
# 3947      Steven Yeun  Taylor, Michigan shout-out on the Oscars: Who ...
# 3948      Steven Yeun  The newest #BestActor #Oscar winner just walke...
# 3949      Steven Yeun  RT @pinkvilla: The cast of Minari set the Osca...
# 3950      Steven Yeun  Steven Yeun @the Oscars... still waiting for B...
# 3951      Steven Yeun  Ok Blue is his Color💙#stevenyeun #Oscars #Acad...
#
#      favorite_count retweet_count                            date  \
# 0                 0             2  Sat Apr 23 12:00:00 +0000 2021
# 1                 0             0  Sat Apr 23 12:00:00 +0000 2021
# 2                 0            49  Sat Apr 23 12:00:00 +0000 2021
# 3                 0            31  Sat Apr 23 12:00:00 +0000 2021
# 4                 0            31  Sat Apr 23 12:00:00 +0000 2021
# ...             ...           ...                             ...
# 3947              5             0  Sat Apr 16 12:00:00 +0000 2021
# 3948              0             0  Sat Apr 16 12:00:00 +0000 2021
# 3949              0             4  Sat Apr 16 12:00:00 +0000 2021
# 3950              0             0  Sat Apr 16 12:00:00 +0000 2021
# 3951              1             0  Sat Apr 16 12:00:00 +0000 2021
#
#                                          processed_text  \
# 0     [actualit, oscars2021, chlo, zhao, made, histo...
# 1     [anthony, hopkins, best, actor, award, father,...
# 2     [let, make, sure, note, british, working, clas...
# 3     [oscar, throwback, anthony, hopkins, best, thi...
# 4     [oscar, throwback, anthony, hopkins, best, thi...
# ...                                                 ...
# 3947  [taylor, michigan, shout, oscars, bingo, card,...
# 3948  [newest, bestactor, oscar, winner, walked, ste...
# 3949  [cast, minari, set, oscars, red, carpet, aligh...
# 3950  [steven, yeun, oscars, still, waiting, best, a...
# 3951  [ok, blue, color, stevenyeun, oscars, academya...
#
#                                                 stemmed  \
# 0     [actualit, oscars2021, chlo, zhao, made, histo...
# 1     [anthoni, hopkin, best, actor, award, father, ...
# 2     [let, make, sure, note, british, work, class, ...
# 3     [oscar, throwback, anthoni, hopkin, best, thin...
# 4     [oscar, throwback, anthoni, hopkin, best, thin...
# ...                                                 ...
# 3947  [taylor, michigan, shout, oscar, bingo, card, ...
# 3948  [newest, bestactor, oscar, winner, walk, step,...
# 3949  [cast, minari, set, oscar, red, carpet, alight...
# 3950  [steven, yeun, oscar, still, wait, best, actor...
# 3951  [ok, blue, color, stevenyeun, oscar, academyaw...
#
#                                                   text2  \
# 0     actualit oscars2021 chlo zhao made history fir...
# 1     anthony hopkins best actor award father becomi...
# 2     let make sure note british working class talen...
# 3     oscar throwback anthony hopkins best think cam...
# 4     oscar throwback anthony hopkins best think cam...
# ...                                                 ...
# 3947  taylor michigan shout oscars bingo card steven...
# 3948  newest bestactor oscar winner walked steps ste...
# 3949  cast minari set oscars red carpet alight alan ...
# 3950  steven yeun oscars still waiting best actor ca...
# 3951      ok blue color stevenyeun oscars academyawards
#
#                                                   text3  \
# 0     actualit oscars2021 chlo zhao made histori fir...
# 1     anthoni hopkin best actor award father becom o...
# 2     let make sure note british work class talent e...
# 3     oscar throwback anthoni hopkin best think camp...
# 4     oscar throwback anthoni hopkin best think camp...
# ...                                                 ...
# 3947  taylor michigan shout oscar bingo card steveny...
# 3948  newest bestactor oscar winner walk step steven...
# 3949  cast minari set oscar red carpet alight alan k...
# 3950  steven yeun oscar still wait best actor catego...
# 3951        ok blue color stevenyeun oscar academyaward
#
#                                       NLTKsentiment_raw  NLTKsentiment
# 0     {'neg': 0.0, 'neu': 0.529, 'pos': 0.471, 'comp...         0.8402
# 1     {'neg': 0.0, 'neu': 0.318, 'pos': 0.682, 'comp...         0.9432
# 2     {'neg': 0.0, 'neu': 0.597, 'pos': 0.403, 'comp...         0.7964
# 3     {'neg': 0.0, 'neu': 0.656, 'pos': 0.344, 'comp...         0.6369
# 4     {'neg': 0.0, 'neu': 0.656, 'pos': 0.344, 'comp...         0.6369
# ...                                                 ...            ...
# 3947  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...         0.0000
# 3948  {'neg': 0.0, 'neu': 0.703, 'pos': 0.297, 'comp...         0.5859
# 3949  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...         0.0000
# 3950  {'neg': 0.0, 'neu': 0.741, 'pos': 0.259, 'comp...         0.6369
# 3951  {'neg': 0.0, 'neu': 0.694, 'pos': 0.306, 'comp...         0.2960
#
# [3952 rows x 11 columns]

# %%
ob1 = train[train["actor_name"] == n[0]]
ob2 = train[train["actor_name"] == n[1]]
ob3 = train[train["actor_name"] == n[2]]
ob4 = train[train["actor_name"] == n[3]]
ob5 = train[train["actor_name"] == n[4]]

# %%
score1 = ob1["NLTKsentiment"].mean()
score2 = ob2["NLTKsentiment"].mean()
score3 = ob3["NLTKsentiment"].mean()
score4 = ob4["NLTKsentiment"].mean()
score5 = ob5["NLTKsentiment"].mean()

print(n[0], "Average Sentiment Score", score1)
print(n[1], "Average Sentiment Score", score2)
print(n[2], "Average Sentiment Score", score3)
print(n[3], "Average Sentiment Score", score4)
print(n[4], "Average Sentiment Score", score5)
# Out:
# Anthony Hopkins Average Sentiment Score 0.4451680000000015
# Riz Ahmed Average Sentiment Score 0.4173220000000014
# Chadwick Boseman Average Sentiment Score 0.24187700000000073
# Gary Oldman Average Sentiment Score 0.43240106382979104
# Steven Yeun Average Sentiment Score 0.34156499999999995

# %%
sentiment = {n[0]: score1,
             n[1]: score2,
             n[2]: score3,
             n[3]: score4,
             n[4]: score5}

# %% [markdown]
# # IMDB Movie Ratings, Rotten Tomatoes Critic Scores

# %%
# Scores were collected on April 24th

# Out of 10
imdb = {n[0]: 8.3,
        n[1]: 7.8,
        n[2]: 7.0,
        n[3]: 6.9,
        n[4]: 7.6}

# Percentage
rt_critics = {n[0]: 0.98,
              n[1]: 0.97,
              n[2]: 0.98,
              n[3]: 0.83,
              n[4]: 0.98}

# Percentage
rt_audience = {n[0]: 0.91,
               n[1]: 0.91,
               n[2]: 0.74,
               n[3]: 0.59,
               n[4]: 0.88}

# %% [markdown]
# # Scoring Model

# %%
# We will calculate the percentage chance that an Actress will win the Oscars.
# Our paper is a commentary on public opinion 
# Therefore we need to scale our metrics  to 0.25 each

def scaling(score, old_range):
    new_range = (0, 0.25)
    mini = old_range[0]
    maxi = old_range[1]
    percent = (score - (mini)) / (maxi - (mini))
    # Scaling formula
    weighted = new_range[1] * percent + new_range[0]
    return weighted

# %%
actor_win = {}
actors_df = pd.DataFrame(columns = ["name", "category", "imdb_audience_score", "rt_critic_score", "rt_audience_score", "sentiment_score", "oscar_win"])

# %%
# Calculating Total Probability of Oscar win and saving results to a csv
for actor in n:
    sentiment_score = scaling(sentiment[actor], (-1, 1))
    imdb_score = scaling(imdb[actor], (0, 10))
    rt_critics_score = scaling(rt_critics[actor], (0, 1))
    rt_audience_score = scaling(rt_audience[actor], (0, 1))
    percentage_win = sentiment_score + imdb_score + rt_critics_score + rt_audience_score
    actor_win[actor] = percentage_win
    actors_df.loc[len(actors_df.index)] = [actor, "actor", imdb_score, rt_critics_score, rt_audience_score, 
                                           sentiment_score, percentage_win]
actors_df.to_csv("actor_results.csv", index = False)

# %%
for key in actor_win:
    print(key, "score is", actor_win[key])
# Out:
# Anthony Hopkins score is 0.8606460000000002
# Riz Ahmed score is 0.8421652500000002
# Chadwick Boseman score is 0.760234625
# Gary Oldman score is 0.7065501329787238
# Steven Yeun score is 0.8226956249999999
